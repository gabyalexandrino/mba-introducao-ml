# %% [markdown]
# # 📊 Projeto -  DATACORP SOLUTIONS
#
#
# |UNIFOR - MBA em Ciência de Dados   |
# |:-----------------------------------|
# |__Professor__: Ms. Alex Lima           |
# |__Disciplina__: Aprendizado de máquina |
#
#
# ## Contexto Geral
#
# A empresa fictícia **Datacorp S/A** é uma organização de médio porte que atua em diversos setores: **marketing**, **vendas**, **recursos humanos**, e **suporte ao cliente**. Como parte da estratégia de transformação digital da empresa, foi criada a iniciativa **Datacorp AI Lab**, com o objetivo de aplicar técnicas de **aprendizado de máquina** para resolver problemas reais de negócio.
#
# Seu time foi contratado para propor, desenvolver e avaliar uma solução de aprendizado de máquina que atenda a uma ou mais demandas da Datacorp.
#
# ---
#
# ## 🎯 Objetivo do Projeto
#
# Desenvolver uma solução baseada em **aprendizado de máquina supervisionado ou não supervisionado** para um ou mais setores da Datacorp, utilizando dados disponíveis publicamente. A solução deverá seguir as etapas típicas de um projeto de machine learning, incluindo:
#
# - Definição do problema
# - Obtenção e preparação dos dados
# - Treinamento e avaliação de modelo(s)
# - Análise de métricas e interpretação dos resultados
# - Conclusão com implicações práticas para a empresa
#
# ---
#
# ## 🗂️ Setores Disponíveis
#
# Os estudantes devem escolher pelo menos um dos setores a seguir. A solução pode ser multidisciplinar.
#
# ### 🛍️ Vendas
# - Previsão de vendas por região ou produto (regressão)
# - Classificação de clientes com risco de churn (classificação)
# - Agrupamento de padrões de consumo (clustering)
#
# ### 📢 Marketing
# - Segmentação de clientes para campanhas personalizadas (clustering)
# - Previsão de resposta a campanhas (classificação)
# - Análise de sentimentos em comentários de clientes (NLP)
#
# ### 👥 Recursos Humanos
# - Previsão de desligamento de funcionários (classificação)
# - Detecção de padrões de absenteísmo (clustering ou regras de associação)
# - Análise de satisfação com base em avaliações internas (análise de sentimentos)
#
# ### ☎️ Suporte ao Cliente
# - Classificação de tipos de chamados (NLP + classificação)
# - Análise de tempo de resolução e SLA (regressão)
# - Agrupamento de reclamações por tema (clustering)
#
# ---
#
# ## 🧪 Requisitos Técnicos
#
# - Buscar e selecionar pelo menos uma base de dados para desenvolver o modelo.
# - Pelo menos **um modelo supervisionado** OU **um modelo não supervisionado** deve ser implementado. Soluções híbridas também são aceitas.
# - Utilizar **métricas adequadas ao tipo de tarefa** (ex: F1-score, AUC, silhouette, etc.).
# - Justificar a escolha dos algoritmos e das métricas.
# - Apresentar uma **análise crítica dos resultados** obtidos.
# - Inclua um dicionário de dados para a versão final do seu dataset.
# - O projeto deve ser **reprodutível**.
#
# ---
#
# ## 🔍 Fontes de Dados
#
# - [Kaggle Datasets](https://www.kaggle.com/datasets)
# - [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php)
# - [OpenML](https://www.openml.org/)
# - [Dados Públicos Gov.br](https://dados.gov.br/)
#
# Qualquer outra fonte que julgar interessante para o projeto.
#
# **Obs.:** Não utilize dados sintéticos.
#
# ---
#
# ## 📫 Entregáveis
#
# - **Notebook(s) com relatório em markdown** contendo:
#   - Identificação
#   - Introdução, definição do problema e dicionário de dados
#   - Desenvolvimento (Pré-processamento e modelo)
#   - Avaliação e métricas
#   - Conclusões e recomendações para a Datacorp
#
# ---
#
# ## 💡 Dica Final
#
# Pensem como cientistas de dados: **Que valor de negócio sua solução pode gerar para a Datacorp?**
#
# ## 📅 Deadlines
#
# - **Deadline**: 26/07/2025 - 23:59
# - **Entrega com atrazo de 1 dia**: Penalidade de 1 ponto na nota final.
# - **Entrega com atrazo de 2 dias**: Penalidade de 2 pontos na nota final.
